# %% [markdown]
# # Scrape HLTV events

# %%
import pandas as pd
from bs4 import BeautifulSoup
import requests
import time
import re

# %% [markdown]
# ## Start a session
# The session needs some cookies combined with a user agent to bypass the captcha.

# %%
s = requests.Session()
s.headers.update({'cookie': '__cfduid=db221c51a4d25bdcc5841cba7831c7b0b1550063953; _ga=GA1.2.1561812873.1550063955; _gid=GA1.2.1646402451.1551795847; _gat=1',
                 'user-agent':'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Ubuntu Chromium/71.0.3578.98 Chrome/71.0.3578.98 Safari/537.36'})

# %% [markdown]
# ## Initiate the Dataframes
#
# I am going to use the following dataframes:
#  - eventsdf: To save all the data about the events.
#   - event: Name of the event
#   - code: Unique code of the event
#   - prizepool: The prizes of the event
#   - date: The date of the event
#   - location: The location of the event, and also the type (LAN/online)
#   - nteams: The amount of teams that participated in the event
#  - teamineventdf: To see which team attended which events.
#   - team: Name of the team
#   - teamcode: Unique code of the team
#   - eventcode: Unique code of the event
#   - placement: Placement of the team at the event
#  - resultsdf: To save the results of all maps.
#   - matchcode: The Unique code of the match
#   - map: The map that the match was played on
#   - team1 & team2: The teams participating in the map
#   - score1 & score2: The score of the map
#   - eventcode: The unique code of the event of the match
#   - stars: The number of stars that was given to the match on HLTV
#   - date: The date of the match
#   - mapnumber: Indicated the sequence of the map in a match
#  - picksdf and bansdf: To save all the vetos.
#   - matchcode: The unique number of the match
#   - team: The name of the team that made the veto
#   - map: The name of the map that was veto'd
#   - priority: The sequencenumber of the veto

# %%
eventsdf = pd.DataFrame(columns=['event', 'code', 'prizepool', 'date', 'location', 'nteams'])
teamineventdf = pd.DataFrame(columns=['team', 'teamcode', 'eventcode', 'placement'])

resultsdf = pd.DataFrame(columns=['matchcode', 'map', 'team1', 'team2', 'score1', 'score2', 'eventcode', 'stars', 'date', 'mapnumber'])
picksdf = pd.DataFrame(columns=['matchcode', 'team', 'map', 'priority'])
bansdf = pd.DataFrame(columns=['matchcode', 'team', 'map', 'priority'])
patternBan = re.compile("removed")
patternPick = re.compile("picked")

# %%
print(len(eventsdf))
# Out:
# 4

# %% [markdown]
# ## Filtering the events
# I am not going to scrape all the matches of all events. Only the matches of the important events. An event is important if an important team participated in it. The teamlist is a list of teams that are in the top 30, or were in the top 30 at 26/03/2018, 25/12/2017, or 26/06/2017. These dates were chosen at random.

# %%
teamlist = []
urls = ["https://www.hltv.org/ranking/teams/2019/march/4", "https://www.hltv.org/ranking/teams/2018/march/26", "https://www.hltv.org/ranking/teams/2017/december/25","https://www.hltv.org/ranking/teams/2017/june/26"]
for url in urls:
    print(url)
    soup = BeautifulSoup(s.get(url).content, 'lxml')
    teams = soup.find_all('div', {"class":"ranked-team standard-box"})
    for team in teams:
        teamcode = team.find('span',{"class":"team-logo"}).find('img')['src'].split('/')[-1]
        if teamcode not in teamlist:
            print(teamcode)
            teamlist.append(teamcode)
# Out:
# https://www.hltv.org/ranking/teams/2019/march/4
# 6665
# 5973
# 4608
# 4869
# 9215
# 6667
# 6211
# 4411
# 5752
# 9565
# 6673
# 7533
# 8120
# 4991
# 4494
# 5995
# 7801
# 7532
# 5310
# 8481
# 8297
# 9183
# 4863
# 8135
# 7606
# 7175
# 5005
# 8008
# 8637
# 8513
# https://www.hltv.org/ranking/teams/2018/march/26
# 6137
# 5929
# 5378
# 6651
# 7367
# 8068
# 6094
# 6902
# 6947
# 7020
# 5906
# 7354
# 5991
# https://www.hltv.org/ranking/teams/2017/december/25
# 6615
# 7557
# 6290
# 8474
# https://www.hltv.org/ranking/teams/2017/june/26
# 7010
# 5974
# 5395
# 6010
# 5422
# 7613
# 7397

# %% [markdown]
# ## The code for the scraping

# %%
totalresults = 0
totalvetos = 0
totalrequests =0
def scrapeResults(eventcode):
    time.sleep(5)
    global resultsdf
    global picksdf
    global bansdf
    global patternBan
    global patternPick
    global totalresults
    global totalrequests
    global totalvetos
    resulturl = "https://www.hltv.org/results?event="+str(eventcode)
    resultSoup = BeautifulSoup(s.get(resulturl).content, 'lxml')
    totalrequests = totalrequests +1
    results = resultSoup.find_all("div", {"class":"result-con"})
    nresults = 0
    nvetos = 0
    for result in results:
        url = "https://www.hltv.org" + result.find("a", {"class":"a-reset"})['href']
        team1Name = result.find("div", {"class":"team1"}).text.strip()
        team2Name = result.find("div", {"class":"team2"}).text.strip()     
        matchCode = result.find("a", {"class":"a-reset"})['href'].split('/')[2]
        stars = str(len(result.find_all("i", {"class":"fa fa-star star"})))
        innersoup = BeautifulSoup(s.get(url).content, "lxml")
        totalrequests = totalrequests +1
        maps = innersoup.find_all("div", {"class": "mapholder"})
        date = innersoup.find("div",{"class":"date"}).text.strip()
        mapnumber = 1
        for result in maps:
            mapname = result.find("div", {'class':'mapname'}).text.strip()
            results = result.find("div", {'class': 'results'})
            if results is not None:
                score1 = results.find_all("span")[0].text.strip()
                score2 = results.find_all("span")[2].text.strip()
                nresults = nresults + 1
                totalresults = totalresults+1
                resultsdf.loc[len(resultsdf)] = [matchCode, mapname, team1Name, team2Name, score1, score2, eventcode, stars, date, mapnumber ]
                mapnumber = mapnumber+1
        try:
            vetos = innersoup.find_all("div",{'class':'standard-box veto-box'})[1].find('div').find_all('div')
            priority = 0
            for veto in vetos:
                nvetos = nvetos+1
                totalvetos = totalvetos + 1
                priority = priority + 1
                string = veto.text.strip()
                if patternBan.search(string):
                    splitstring = string.split(' removed ')
                    bansdf.loc[len(bansdf)] = [matchCode, splitstring[0][3:], splitstring[-1], priority]
                elif patternPick.search(string):
                    splitstring = string.split(' picked ')
                    picksdf.loc[len(picksdf)] = [matchCode, splitstring[0][3:], splitstring[-1], priority]
        except IndexError as e:
            1+1
            
    print("results for event: "+ str(eventcode) + " scraped, maps scraped: "+str(nresults)+", vetos scraped: "+str(nvetos) )
    print("total results: " + str(totalresults) + "|| total vetos: "+str(totalvetos))

def scrapeEvent(eventurl):
    global eventsdf
    global teamineventdf
    global teamlist
    global totalrequests
    scrapeEventResults = False
    eventsoup = BeautifulSoup(s.get(eventurl).content, "lxml")
    totalrequests = totalrequests+1
    eventname = eventurl.split("/")[-1]
    eventcode = eventurl.split("/")[-2]
    prizepool = eventsoup.find("td", {"class":"prizepool text-ellipsis"}).text.strip()
    date = eventsoup.find("td", {"class":"eventdate"}).find("span").text.strip()
    location = eventsoup.find("td", {"class":"location gtSmartphone-only"}).find("span", {"class":"text-ellipsis"}).text.strip()
    nteams = eventsoup.find("td", {"class":"teamsNumber"}).text.strip()
    eventsdf.loc[len(eventsdf)] = [eventname, eventcode, prizepool, date, location, nteams]
    teamsInEvent = eventsoup.find_all("div",{"class":"placement"})
    for team in teamsInEvent:
        try:
            teamstring = team.find("div",{"class":"team"}).find("a")['href'].split('/')
            teamname = teamstring[-1]
            teamcode = teamstring[-2]
            if teamcode in teamlist:
                scrapeEventResults = True
            placement = team.find_all("div")[1].text.strip()
            teamineventdf.loc[len(teamineventdf)] = [teamname, teamcode, eventcode, placement]
        except TypeError as e:
            1+1
    if scrapeEventResults:
        scrapeResults(eventcode)
    else:
        print("event with eventcode: "+str(eventcode)+" not scraped")    

        
def scrapePage(url):
    global totalrequests
    print("scraping page: "+url)
    soup = BeautifulSoup(s.get(url).content, "lxml")
    totalrequests = totalrequests +1
    sublists = soup.find_all("div", {"class": "events-month"})
    for sublist in sublists:
        events = sublist.find_all("a", {"class": "a-reset small-event standard-box"})
        for event in events:
            url = "https://www.hltv.org" + event['href']
            scrapeEvent(url)
            time.sleep(1)
    print("total requests so far: "+str(totalrequests))
            
def scrape():
    for i in range(30, 40):
        offset = i*50
        url = "https://www.hltv.org/events/archive?offset="+str(offset)
        scrapePage(url)
        save()
        
def save():
    startsave = int(round(time.time() * 1000))
    global eventsdf
    global teamineventdf
    global resultsdf
    global picksdf
    global bansdf
    resultsdf.to_csv('results2017-2.csv')
    picksdf.to_csv('picks2017-2.csv')
    bansdf.to_csv('bans2017-2.csv')
    eventsdf.to_csv('events2017-2.csv')
    teamineventdf.to_csv('teaminevents2017-2.csv')
    endsave = int(round(time.time() * 1000))
    saveduration = endsave - startsave
    print("saved, duration of save in milliseconds: "+str(saveduration))

# %% [markdown]
# ## The script for the scraping

# %%
scrape()
# Out:
# scraping page: https://www.hltv.org/events/archive?offset=1500
# event with eventcode: 2915 not scraped
# event with eventcode: 2914 not scraped
# event with eventcode: 2913 not scraped
# results for event: 2911 scraped, maps scraped: 8, vetos scraped: 21
# total results: 8|| total vetos: 21
# event with eventcode: 2910 not scraped
# results for event: 2757 scraped, maps scraped: 16, vetos scraped: 49
# total results: 24|| total vetos: 70
# results for event: 2898 scraped, maps scraped: 13, vetos scraped: 42
# total results: 37|| total vetos: 112
# results for event: 2724 scraped, maps scraped: 30, vetos scraped: 112
# total results: 67|| total vetos: 224
# results for event: 2722 scraped, maps scraped: 27, vetos scraped: 112
# total results: 94|| total vetos: 336
# results for event: 2841 scraped, maps scraped: 60, vetos scraped: 135
# total results: 154|| total vetos: 471
# results for event: 2860 scraped, maps scraped: 33, vetos scraped: 105
# total results: 187|| total vetos: 576
# results for event: 2872 scraped, maps scraped: 60, vetos scraped: 168
# total results: 247|| total vetos: 744
# results for event: 2729 scraped, maps scraped: 90, vetos scraped: 0
# total results: 337|| total vetos: 744
# results for event: 2728 scraped, maps scraped: 90, vetos scraped: 0
# total results: 427|| total vetos: 744
# results for event: 2842 scraped, maps scraped: 73, vetos scraped: 145
# total results: 500|| total vetos: 889
# event with eventcode: 2886 not scraped
# results for event: 2549 scraped, maps scraped: 10, vetos scraped: 49
# total results: 5623|| total vetos: 15025
# results for event: 2550 scraped, maps scraped: 11, vetos scraped: 35
# total results: 5634|| total vetos: 15060
# results for event: 2544 scraped, maps scraped: 32, vetos scraped: 131
# total results: 5666|| total vetos: 15191
# event with eventcode: 2534 not scraped
# event with eventcode: 2545 not scraped
# event with eventcode: 2501 not scraped
# results for event: 2497 scraped, maps scraped: 30, vetos scraped: 106
# total results: 5696|| total vetos: 15297
# results for event: 2340 scraped, maps scraped: 96, vetos scraped: 21
# total results: 5792|| total vetos: 15318
# results for event: 2306 scraped, maps scraped: 37, vetos scraped: 210
# total results: 5829|| total vetos: 15528
# event with eventcode: 2540 not scraped
# event with eventcode: 2542 not scraped
# event with eventcode: 2537 not scraped
# event with eventcode: 2528 not scraped
# results for event: 2532 scraped, maps scraped: 13, vetos scraped: 38
# total results: 5842|| total vetos: 15566
# event with eventcode: 2529 not scraped
# results for event: 2452 scraped, maps scraped: 35, vetos scraped: 182
# total results: 5877|| total vetos: 15748
# results for event: 2410 scraped, maps scraped: 39, vetos scraped: 203
# total results: 5916|| total vetos: 15951
# event with eventcode: 2527 not scraped
# event with eventcode: 2466 not scraped
# results for event: 2526 scraped, maps scraped: 19, vetos scraped: 21
# total results: 5935|| total vetos: 15972
# event with eventcode: 2499 not scraped
# event with eventcode: 2508 not scraped
# total requests so far: 4332
# saved, duration of save in milliseconds: 67
# scraping page: https://www.hltv.org/events/archive?offset=1850
# results for event: 2524 scraped, maps scraped: 37, vetos scraped: 105
# total results: 5972|| total vetos: 16077
# event with eventcode: 2525 not scraped
# event with eventcode: 2523 not scraped
# event with eventcode: 2521 not scraped
# event with eventcode: 2520 not scraped
# event with eventcode: 2517 not scraped
# event with eventcode: 2516 not scraped
# event with eventcode: 2513 not scraped
# event with eventcode: 2518 not scraped
# event with eventcode: 2522 not scraped
# results for event: 2489 scraped, maps scraped: 6, vetos scraped: 0
# total results: 5978|| total vetos: 16077
# event with eventcode: 2514 not scraped
# results for event: 2512 scraped, maps scraped: 7, vetos scraped: 21
# total results: 5985|| total vetos: 16098
# event with eventcode: 2507 not scraped
# event with eventcode: 2505 not scraped
# results for event: 2369 scraped, maps scraped: 183, vetos scraped: 7
# total results: 6168|| total vetos: 16105
# results for event: 2368 scraped, maps scraped: 178, vetos scraped: 0
# total results: 6346|| total vetos: 16105
# results for event: 2386 scraped, maps scraped: 54, vetos scraped: 0
# total results: 6400|| total vetos: 16105
# event with eventcode: 2492 not scraped
# event with eventcode: 2433 not scraped
# results for event: 2390 scraped, maps scraped: 70, vetos scraped: 364
# total results: 6470|| total vetos: 16469
# results for event: 2482 scraped, maps scraped: 57, vetos scraped: 7
# total results: 6527|| total vetos: 16476
# event with eventcode: 2311 not scraped
# event with eventcode: 2388 not scraped
# event with eventcode: 2498 not scraped
# event with eventcode: 2496 not scraped
# event with eventcode: 2491 not scraped
# event with eventcode: 2490 not scraped
# results for event: 2397 scraped, maps scraped: 34, vetos scraped: 91
# total results: 6561|| total vetos: 16567
# event with eventcode: 2409 not scraped
# event with eventcode: 2488 not scraped
# event with eventcode: 2354 not scraped
# event with eventcode: 2485 not scraped
# results for event: 2345 scraped, maps scraped: 15, vetos scraped: 42
# total results: 6576|| total vetos: 16609
# results for event: 2239 scraped, maps scraped: 26, vetos scraped: 139
# total results: 6602|| total vetos: 16748
# results for event: 2478 scraped, maps scraped: 23, vetos scraped: 112
# total results: 6625|| total vetos: 16860
# event with eventcode: 2484 not scraped
# event with eventcode: 2457 not scraped
# event with eventcode: 2475 not scraped
# event with eventcode: 2468 not scraped
# event with eventcode: 2464 not scraped
# results for event: 2469 scraped, maps scraped: 7, vetos scraped: 21
# total results: 6632|| total vetos: 16881
# event with eventcode: 2467 not scraped
# event with eventcode: 2463 not scraped
# event with eventcode: 2450 not scraped
# results for event: 2395 scraped, maps scraped: 29, vetos scraped: 83
# total results: 6661|| total vetos: 16964
# event with eventcode: 2474 not scraped
# event with eventcode: 2462 not scraped
# results for event: 2413 scraped, maps scraped: 17, vetos scraped: 48
# total results: 6678|| total vetos: 17012
# results for event: 2420 scraped, maps scraped: 44, vetos scraped: 145
# total results: 6722|| total vetos: 17157
# total requests so far: 5035
# saved, duration of save in milliseconds: 79
# scraping page: https://www.hltv.org/events/archive?offset=1900
# results for event: 2419 scraped, maps scraped: 55, vetos scraped: 182
# total results: 6777|| total vetos: 17339
# event with eventcode: 2349 not scraped
# results for event: 2161 scraped, maps scraped: 15, vetos scraped: 36
# total results: 6792|| total vetos: 17375
# event with eventcode: 2461 not scraped
# event with eventcode: 2460 not scraped
# event with eventcode: 2459 not scraped
# results for event: 2435 scraped, maps scraped: 11, vetos scraped: 21
# total results: 6803|| total vetos: 17396
# results for event: 2411 scraped, maps scraped: 39, vetos scraped: 130
# total results: 6842|| total vetos: 17526
# event with eventcode: 2421 not scraped
# event with eventcode: 2456 not scraped
# event with eventcode: 2458 not scraped
# results for event: 2334 scraped, maps scraped: 11, vetos scraped: 21
# total results: 6853|| total vetos: 17547
# event with eventcode: 2451 not scraped
# results for event: 2449 scraped, maps scraped: 8, vetos scraped: 28
# total results: 6861|| total vetos: 17575
# event with eventcode: 2439 not scraped
# event with eventcode: 2455 not scraped
# event with eventcode: 2158 not scraped
# event with eventcode: 2448 not scraped
# event with eventcode: 2446 not scraped
# results for event: 2445 scraped, maps scraped: 8, vetos scraped: 35
# total results: 6869|| total vetos: 17610
# event with eventcode: 2440 not scraped
# results for event: 2296 scraped, maps scraped: 83, vetos scraped: 82
# total results: 6952|| total vetos: 17692
# event with eventcode: 2444 not scraped
# results for event: 2441 scraped, maps scraped: 18, vetos scraped: 35
# total results: 6970|| total vetos: 17727
# results for event: 2443 scraped, maps scraped: 9, vetos scraped: 35
# total results: 6979|| total vetos: 17762
# results for event: 2112 scraped, maps scraped: 24, vetos scraped: 91
# total results: 7003|| total vetos: 17853
# event with eventcode: 2442 not scraped
# event with eventcode: 2438 not scraped
# event with eventcode: 2436 not scraped
# event with eventcode: 2418 not scraped
# event with eventcode: 2437 not scraped
# results for event: 2406 scraped, maps scraped: 26, vetos scraped: 63
# total results: 7029|| total vetos: 17916
# total results: 7717|| total vetos: 19728
# event with eventcode: 2359 not scraped
# results for event: 2366 scraped, maps scraped: 30, vetos scraped: 0
# total results: 7747|| total vetos: 19728
# results for event: 2361 scraped, maps scraped: 29, vetos scraped: 0
# total results: 7776|| total vetos: 19728
# results for event: 2353 scraped, maps scraped: 14, vetos scraped: 51
# total results: 7790|| total vetos: 19779
# results for event: 2371 scraped, maps scraped: 2, vetos scraped: 7
# total results: 7792|| total vetos: 19786
# event with eventcode: 2365 not scraped
# results for event: 2326 scraped, maps scraped: 29, vetos scraped: 60
# total results: 7821|| total vetos: 19846
# results for event: 2370 scraped, maps scraped: 2, vetos scraped: 7
# total results: 7823|| total vetos: 19853
# results for event: 2377 scraped, maps scraped: 8, vetos scraped: 28
# total results: 7831|| total vetos: 19881
# event with eventcode: 2376 not scraped
# event with eventcode: 2375 not scraped
# event with eventcode: 2374 not scraped
# results for event: 2338 scraped, maps scraped: 4, vetos scraped: 6
# total results: 7835|| total vetos: 19887
# event with eventcode: 2352 not scraped
# event with eventcode: 2373 not scraped
# event with eventcode: 2336 not scraped
# event with eventcode: 2344 not scraped
# event with eventcode: 2360 not scraped
# results for event: 2335 scraped, maps scraped: 31, vetos scraped: 82
# total results: 7866|| total vetos: 19969
# results for event: 2346 scraped, maps scraped: 13, vetos scraped: 40
# total results: 7879|| total vetos: 20009
# event with eventcode: 2358 not scraped
# results for event: 2337 scraped, maps scraped: 29, vetos scraped: 67
# total results: 7908|| total vetos: 20076
# event with eventcode: 2341 not scraped
# results for event: 2314 scraped, maps scraped: 20, vetos scraped: 78
# total results: 7928|| total vetos: 20154
# results for event: 2355 scraped, maps scraped: 3, vetos scraped: 6
# total results: 7931|| total vetos: 20160
# total requests so far: 5812
# saved, duration of save in milliseconds: 86

# %% [markdown]
# ## Combining the csv files

# %%
csvs = ["events", "bans", "picks", "results", "teaminevents"]

for csv in csvs:
    path1 = "HLTV project/csvfiles/2018/"+csv+"2018.csv"
    path2 = "HLTV project/csvfiles/2017/"+csv+"2017.csv"
    finalpath = "HLTV project/csvfiles/2017-2019/"+csv+".csv"
    pd.read_csv(path1).append(pd.read_csv(path2), ignore_index=True).to_csv(finalpath)

# %% [markdown]
# ## Tests
# I tested the scrapeEvent function, and the scrapeResult function. It gave the output I expected.

# %%
scrapeEvent("https://www.hltv.org/events/4376/qiwi-teamplay-season-3")
print(eventsdf)
print(teamineventdf)

scrapeResults(4322)
print(resultsdf)
print(picksdf)
print(bansdf)
# Out:
#   matchcode     map         team1     team2 score1 score2 eventcode stars  \
# 0   2330292  Mirage  PELAFUSTANES  Rejected     16     14      4322     0
# 1   2330292   Dust2  PELAFUSTANES  Rejected     16      4      4322     0
#
#                    date mapnumber
# 0  13th of January 2019         1
# 1  13th of January 2019         2
#   matchcode          team     map priority
# 0   2330292      Rejected  Mirage        3
# 1   2330292  PELAFUSTANES   Dust2        4
#   matchcode          team       map priority
# 0   2330292      Rejected     Cache        1
# 1   2330292  PELAFUSTANES   Inferno        2
# 2   2330292      Rejected     Train        5
# 3   2330292  PELAFUSTANES  Overpass        6
